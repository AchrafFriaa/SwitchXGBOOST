# %%
import numpy as np
import serial
import serial.tools.list_ports
import sys
import base64
from bitstring import Bits
import time
import pandas as pd
from IPython.display import clear_output

def read_hex(hexstring):
    #hexstring=''.join(reversed(hexstring))
    if len(hexstring) == 999:
       print('error')
    else:
        bx1, bx2 = hexstring[2:4],hexstring[4:6]
        bx =bx2+bx1
        by1,by2 = hexstring[6:8],hexstring[8:10]
        by= by2+by1
        bz1,bz2 = hexstring[10:12],hexstring[12:14]
        bz = bz2+bz1
        Bx = (Bits(hex=bx).int)*0.13
        By = (Bits(hex=by).int)*0.13
        Bz = (Bits(hex=bz).int)*0.13
        B = np.array([Bx,By,Bz])
        return B

def readSensor(serial): 
    try:
        # request data   21 
        serial.flushInput()
        string = "5A E8 5A DF 5A CB" #Long range - Fast mode - Start periodic readout
        get_fw_v = "D2 2D"
        cmd_bytes = bytearray.fromhex(string)
        #ser.write(cmd_bytes)
        
        
        serial.write(cmd_bytes)
        
        
        msg_b = serial.read(8)
        #print(msg_b)
        encoded = str(base64.b16encode(msg_b))
        encoded = encoded.replace("b'","")
        encoded = encoded.replace("'","")
        B = read_hex(encoded)
        clear_output(wait=True)
        print(B)
        

    except KeyboardInterrupt:
        print("User interrupt encountered. Exiting...")
        time.sleep(3)
        serial.flushInput()
        serial.flushOutput()
        serial.close()
        sys.exit()
    except:
        # for all other kinds of error, but not specifying which one
        print("Device disconnected")
        time.sleep(3)
        serial.flushInput()
        serial.flushOutput()
        serial.close()
        sys.exit()


def getXMCserialConnection(): 
    # returns serial port object
    # opens the serial port to communicate with the XMC
    global ser
    ports = list(serial.tools.list_ports.comports())
    if (len(ports) != 0):
        for p in ports:
            if ((p.pid == 261) & (p.vid == 4966)): # pid and vid from xmc
                #print("XMC found on port: " + p.device)
                try:
                    ser = serial.Serial(p.device, 115200)
                    #print('Serial Connection Done')
                    return ser
                except Exception:
                    print('Please unplug then plug back the device')
                    print('Serial Connection Done')
    print('ERROR(getSerialConnection) - Cannot Find a device.')
    sys.exit()

# %%
ser = getXMCserialConnection()
while True:
    
    b=readSensor(ser)
    time.sleep(1)
# Out:
# [-0.13  0.   -0.52]
# Device disconnected
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "<ipython-input-37-da794c928205>", line 38, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-35-da794c928205>", line 38, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-27-3076f6350baf>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-24-2d2940339d73>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-17-765f9e0fe838>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-15-765f9e0fe838>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-13-765f9e0fe838>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-11-765f9e0fe838>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-7-c792a6347687>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-5-16e2733c1b9b>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-3-bc8cabf97042>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
#   File "<ipython-input-1-bc8cabf97042>", line 37, in readSensor
#     serial.write(cmd_bytes)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py", line 323, in write
#     raise writeTimeoutError
# serial.serialutil.SerialTimeoutException: Write timeout
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-38-15cc954d47c0>", line 4, in <module>
#     b=readSensor(ser)
#   File "<ipython-input-37-da794c928205>", line 65, in readSensor
#     sys.exit()
# SystemExit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Friaa\AppData\Local\Continuum\anaconda3\lib\inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# SerialTimeoutException                    Traceback (most recent call last)
# <ipython-input-37-da794c928205> in readSensor(serial)
#      37
# ---> 38         serial.write(cmd_bytes)
#      39
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-35-da794c928205> in readSensor(serial)
#      37
# ---> 38         serial.write(cmd_bytes)
#      39
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-27-3076f6350baf> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-24-2d2940339d73> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-17-765f9e0fe838> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-15-765f9e0fe838> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-13-765f9e0fe838> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-11-765f9e0fe838> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-7-c792a6347687> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-5-16e2733c1b9b> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-3-bc8cabf97042> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# <ipython-input-1-bc8cabf97042> in readSensor(serial)
#      36
# ---> 37         serial.write(cmd_bytes)
#      38
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     322                 if n.value != len(data):
# --> 323                     raise writeTimeoutError
#     324                 return n.value
#
# SerialTimeoutException: Write timeout
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-38-15cc954d47c0> in <module>
#       3
# ----> 4     b=readSensor(ser)
#       5     time.sleep(1)
#
# <ipython-input-37-da794c928205> in readSensor(serial)
#      64         serial.close()
# ---> 65         sys.exit()
#      66
#
# SystemExit:
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2036                            'the full traceback.\n']
#    2037                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2038                                                                      value))
#    2039                 else:
#    2040                     try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     700                     chained_exceptions_tb_offset, context)
#     701                 + chained_exception_message
# --> 702                 + out_list)
#     703
#     704         return out_list
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
